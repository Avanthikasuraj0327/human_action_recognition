# %%
import torch
print("GPU available:", torch.cuda.is_available())
# Out:
# GPU available: True

# %%
# !pip install torchvision opencv-python seaborn -q

# %%
import os, cv2, torch, numpy as np, random
import torchvision.models as tv_models
import torchvision.transforms as transforms
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.layers import (Input, LSTM, GRU, SimpleRNN, Dense,
    Dropout, GlobalAveragePooling1D, Attention, Concatenate, LayerNormalization,
    MultiHeadAttention, Bidirectional)
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import warnings; warnings.filterwarnings("ignore")
print("TF:", tf.__version__, " | Torch:", torch.__version__)
# Out:
# TF: 2.19.0  | Torch: 2.9.0+cu126

# %%
dataset_root = "/kaggle/input/datasets/avanthikasuraj/ucf101-20/ucf101 dataset"

train_path = os.path.join(dataset_root, "train")
val_path   = os.path.join(dataset_root, "val")
test_path  = os.path.join(dataset_root, "test")

# %%
classes = sorted([d for d in os.listdir(train_path) 
           if os.path.isdir(os.path.join(train_path, d))])

label_map = {cls:i for i,cls in enumerate(classes)}
print(f"Found {len(classes)} classes:", classes)
# Out:
# Found 25 classes: ['ApplyEyeMakeup', 'ApplyLipstick', 'BabyCrawling', 'Basketball', 'BenchPress', 'Biking', 'BlowDryHair', 'Bowling', 'CliffDiving', 'CricketShot', 'SumoWrestling', 'Surfing', 'Swing', 'TableTennisShot', 'TaiChi', 'TennisSwing', 'ThrowDiscus', 'TrampolineJumping', 'Typing', 'UnevenBars', 'VolleyballSpiking', 'WalkingWithDog', 'WallPushups', 'WritingOnBoard', 'YoYo']

# %% [markdown]
# Pretrained Models

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ── CNN-1: ResNet34 ──────────────────────────────────────────────────
resnet = tv_models.resnet34(pretrained=True)
resnet = torch.nn.Sequential(*list(resnet.children())[:-1])   # remove FC → output (512,)
resnet = resnet.to(device).eval()

# ── CNN-2: MobileNetV2 ───────────────────────────────────────────────
mobilenet = tv_models.mobilenet_v2(pretrained=True)
mobilenet.classifier = torch.nn.Identity()                     # remove classifier → output (1280,)
mobilenet = mobilenet.to(device).eval()

print("ResNet34 feature dim   : 512")
print("MobileNetV2 feature dim: 1280")
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 167MB/s]
# ResNet34 feature dim   : 512
# MobileNetV2 feature dim: 1280

# %% [markdown]
# Fine tuning

# %%
# ── Fine-tune ResNet34: freeze all, unfreeze layer4 + fc ────────────
for param in resnet.parameters():
    param.requires_grad = False

# Unfreeze the last residual block (layer4 is index 7 in Sequential)
for param in list(resnet.children())[7].parameters():
    param.requires_grad = True

trainable_resnet = sum(p.numel() for p in resnet.parameters() if p.requires_grad)
total_resnet     = sum(p.numel() for p in resnet.parameters())
print(f"ResNet34  — trainable: {trainable_resnet:,} / {total_resnet:,}")

# ── Fine-tune MobileNetV2: freeze all, unfreeze last 3 InvertedResidual blocks
for param in mobilenet.parameters():
    param.requires_grad = False

for block in list(mobilenet.features.children())[-3:]:
    for param in block.parameters():
        param.requires_grad = True

trainable_mob = sum(p.numel() for p in mobilenet.parameters() if p.requires_grad)
total_mob     = sum(p.numel() for p in mobilenet.parameters())
print(f"MobileNetV2 — trainable: {trainable_mob:,} / {total_mob:,}")
# Out:
# ResNet34  — trainable: 13,114,368 / 21,284,672
# MobileNetV2 — trainable: 1,206,080 / 2,223,872

# %%
# Training transform — spatial augmentations applied per frame
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((128, 128)),          # smaller = faster; still fine for ResNet
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.2),
    transforms.RandomRotation(degrees=15),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],   # ImageNet stats
                         std=[0.229, 0.224, 0.225])
])

# Val/Test transform — deterministic, no augmentation
eval_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# Extract Features

# %%
SEQ_LEN    = 30    
FRAME_STEP = 5     

def extract_features(video_path, transform, is_train=False):
    cap = cv2.VideoCapture(video_path)
    features = []
    frame_idx = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        if frame_idx % FRAME_STEP == 0:
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            img = transform(frame_rgb).unsqueeze(0).to(device)

            with torch.no_grad():
                f_resnet    = resnet(img).squeeze().cpu().numpy()         # (512,)
                f_mobilenet = mobilenet(img).squeeze().cpu().numpy()      # (1280,)

            combined = np.concatenate([f_resnet, f_mobilenet])            # (1792,)
            features.append(combined)
        frame_idx += 1

    cap.release()
    return np.array(features)   # (T, 1792)

# %% [markdown]
# Temporal Sequence Creation

# %%
def make_fixed_length_sequence(features, seq_len=SEQ_LEN):
    T = len(features)
    if T == 0:
        return None
    if T >= seq_len:
        # uniformly sample seq_len indices
        indices = np.linspace(0, T - 1, seq_len, dtype=int)
        return features[indices]
    else:
        # pad with zeros at the end
        pad = np.zeros((seq_len - T, features.shape[1]))
        return np.vstack([features, pad])

# %% [markdown]
# Dataset Builder

# %%
def build_dataset(data_path, transform, is_train=False, desc=""):
    X, y = [], []
    for cls in classes:
        folder = os.path.join(data_path, cls)
        if not os.path.exists(folder):
            continue
        print(f"  Processing class: {cls}")
        for video_file in tqdm(os.listdir(folder), desc=cls, leave=False):
            video_path = os.path.join(folder, video_file)
            feats = extract_features(video_path, transform, is_train)
            if len(feats) < 5:          # skip very short / corrupt clips
                continue
            seq = make_fixed_length_sequence(feats, SEQ_LEN)
            if seq is None:
                continue
            X.append(seq)
            y.append(label_map[cls])
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.int32)


print("SEQ_LEN:", SEQ_LEN, " | feature_dim: 1792")
# Out:
# SEQ_LEN: 30  | feature_dim: 1792

# %% [markdown]
# Build Train / Val / Test

# %%
print("=" * 50)
print("Building TRAIN dataset ...")
X_train, y_train = build_dataset(train_path, train_transform, is_train=True)
print(f"Train: {X_train.shape}, labels: {y_train.shape}")

print("=" * 50)
print("Building VAL dataset ...")
X_val, y_val = build_dataset(val_path, eval_transform)
print(f"Val  : {X_val.shape}, labels: {y_val.shape}")

print("=" * 50)
print("Building TEST dataset ...")
X_test, y_test = build_dataset(test_path, eval_transform)
print(f"Test : {X_test.shape}, labels: {y_test.shape}")
# Out:
# ==================================================
# Building TRAIN dataset ...
#   Processing class: ApplyEyeMakeup
#   Processing class: ApplyLipstick
#   Processing class: BabyCrawling
#   Processing class: Basketball
#   Processing class: BenchPress
#   Processing class: Biking
#   Processing class: BlowDryHair
#   Processing class: Bowling
#   Processing class: CliffDiving
#   Processing class: CricketShot
#   Processing class: SumoWrestling
#   Processing class: Surfing
#   Processing class: Swing
#   Processing class: TableTennisShot
#   Processing class: TaiChi
#   Processing class: TennisSwing
#   Processing class: ThrowDiscus
#   Processing class: TrampolineJumping
#   Processing class: Typing
#   Processing class: UnevenBars
#   Processing class: VolleyballSpiking
#   Processing class: WalkingWithDog
#   Processing class: WallPushups
#   Processing class: WritingOnBoard
#   Processing class: YoYo
# Train: (2587, 30, 1792), labels: (2587,)
# ==================================================
# Building VAL dataset ...
#   Processing class: ApplyEyeMakeup
#   Processing class: ApplyLipstick
#   Processing class: BabyCrawling
#   Processing class: Basketball
#   Processing class: BenchPress
#   Processing class: Biking
#   Processing class: BlowDryHair
#   Processing class: Bowling
#   Processing class: CricketShot
#   Processing class: SumoWrestling
#   Processing class: Surfing
#   Processing class: Swing
#   Processing class: TableTennisShot
#   Processing class: TaiChi
#   Processing class: TennisSwing
#   Processing class: ThrowDiscus
#   Processing class: TrampolineJumping
#   Processing class: Typing
#   Processing class: UnevenBars
#   Processing class: VolleyballSpiking
#   Processing class: WalkingWithDog
#   Processing class: WallPushups
#   Processing class: WritingOnBoard
#   Processing class: YoYo
# Val  : (411, 30, 1792), labels: (411,)
# ==================================================
# Building TEST dataset ...
#   Processing class: ApplyEyeMakeup
#   Processing class: ApplyLipstick
#   Processing class: BabyCrawling
#   Processing class: Basketball
#   Processing class: BenchPress
#   Processing class: Biking
#   Processing class: BlowDryHair
#   Processing class: Bowling
#   Processing class: CliffDiving
#   Processing class: CricketShot
#   Processing class: SumoWrestling
#   Processing class: Surfing
#   Processing class: Swing
#   Processing class: TableTennisShot
#   Processing class: TaiChi
#   Processing class: TennisSwing
#   Processing class: ThrowDiscus
#   Processing class: TrampolineJumping
#   Processing class: Typing
#   Processing class: UnevenBars
#   Processing class: VolleyballSpiking
#   Processing class: WalkingWithDog
#   Processing class: WallPushups
#   Processing class: WritingOnBoard
#   Processing class: YoYo
# Test : (443, 30, 1792), labels: (443,)

# %% [markdown]
# Embedding Layer: Project 1792-d → 256-d

# %%
from tensorflow.keras.layers import TimeDistributed

def add_embedding_projection(inputs, embed_dim=256):
    x = TimeDistributed(Dense(embed_dim, activation="relu"))(inputs)
    x = TimeDistributed(LayerNormalization())(x)
    return x

FEATURE_DIM = X_train.shape[2]   # 1792
NUM_CLASSES  = len(classes)
EMBED_DIM    = 256
print(f"Feature dim: {FEATURE_DIM}, Embed dim: {EMBED_DIM}, Classes: {NUM_CLASSES}")
# Out:
# Feature dim: 1792, Embed dim: 256, Classes: 25

# %% [markdown]
# Training Callbacks

# %%
def get_callbacks(model_name):
    return [
        EarlyStopping(monitor="val_accuracy", patience=7,
                      restore_best_weights=True, verbose=1),
        ReduceLROnPlateau(monitor="val_loss", factor=0.5,
                          patience=3, min_lr=1e-6, verbose=1),
        ModelCheckpoint(f"/kaggle/working/{model_name}_best.keras",
                        monitor="val_accuracy", save_best_only=True, verbose=0)
    ]

# %% [markdown]
# RNN

# %%
def build_rnn(lr=0.001):
    inp = Input(shape=(SEQ_LEN, FEATURE_DIM))
    x   = add_embedding_projection(inp, EMBED_DIM)          # (B, 30, 256)
    x   = SimpleRNN(128, return_sequences=True, dropout=0.3)(x)
    x   = SimpleRNN(64,  dropout=0.3)(x)
    x   = Dense(64, activation="relu")(x)
    x   = Dropout(0.4)(x)
    out = Dense(NUM_CLASSES, activation="softmax")(x)
    m   = Model(inp, out, name="RNN")
    m.compile(optimizer=Adam(lr), loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
    return m

rnn_model = build_rnn()
rnn_model.summary()
# Out:
# Model: "RNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 30, 1792)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 30, 256)        │       459,008 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 30, 256)        │           512 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 30, 128)        │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ (None, 64)             │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 25)             │         1,625 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 526,937 (2.01 MB)
#  Trainable params: 526,937 (2.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# LSTM

# %%
def build_lstm(lr=0.001):
    inp = Input(shape=(SEQ_LEN, FEATURE_DIM))
    x   = add_embedding_projection(inp, EMBED_DIM)
    x   = LSTM(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.2)(x)
    x   = LSTM(64,  dropout=0.3)(x)
    x   = Dense(64, activation="relu")(x)
    x   = Dropout(0.4)(x)
    out = Dense(NUM_CLASSES, activation="softmax")(x)
    m   = Model(inp, out, name="LSTM")
    m.compile(optimizer=Adam(lr), loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
    return m

lstm_model = build_lstm()
lstm_model.summary()
# Out:
# Model: "LSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 30, 1792)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 30, 256)        │       459,008 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 30, 256)        │           512 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 30, 128)        │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 25)             │         1,625 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 711,833 (2.72 MB)
#  Trainable params: 711,833 (2.72 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# GRU

# %%
def build_gru(lr=0.001):
    inp = Input(shape=(SEQ_LEN, FEATURE_DIM))
    x   = add_embedding_projection(inp, EMBED_DIM)
    x   = GRU(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.2)(x)
    x   = GRU(64,  dropout=0.3)(x)
    x   = Dense(64, activation="relu")(x)
    x   = Dropout(0.4)(x)
    out = Dense(NUM_CLASSES, activation="softmax")(x)
    m   = Model(inp, out, name="GRU")
    m.compile(optimizer=Adam(lr), loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
    return m

gru_model = build_gru()
gru_model.summary()
# Out:
# Model: "GRU"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 30, 1792)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_4              │ (None, 30, 256)        │       459,008 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_5              │ (None, 30, 256)        │           512 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 30, 128)        │       148,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 64)             │        37,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 25)             │         1,625 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 650,777 (2.48 MB)
#  Trainable params: 650,777 (2.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Bidirectional LSTM + Multi Head Attention

# %%
def build_attention_model(lr=0.001):
    inp = Input(shape=(SEQ_LEN, FEATURE_DIM))
    x   = add_embedding_projection(inp, EMBED_DIM)                         # (B,30,256)

    # Bidirectional LSTM for richer temporal representation
    x   = Bidirectional(LSTM(128, return_sequences=True, dropout=0.3))(x)  # (B,30,256)

    # Multi-Head Self-Attention over the temporal dimension
    attn_out = MultiHeadAttention(num_heads=4, key_dim=64)(x, x)           # (B,30,256)
    x        = LayerNormalization()(x + attn_out)                          # residual

    x   = GlobalAveragePooling1D()(x)                                      # (B,256)
    x   = Dense(128, activation="relu")(x)
    x   = Dropout(0.4)(x)
    out = Dense(NUM_CLASSES, activation="softmax")(x)

    m = Model(inp, out, name="BiLSTM_Attention")
    m.compile(optimizer=Adam(lr), loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
    return m

attention_model = build_attention_model()
attention_model.summary()
# Out:
# Model: "BiLSTM_Attention"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 30, 1792)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_6  │ (None, 30, 256)   │    459,008 │ input_layer_7[0]… │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_7  │ (None, 30, 256)   │        512 │ time_distributed… │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 30, 256)   │    394,240 │ time_distributed… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 256)   │    263,168 │ bidirectional[0]… │
# │ (MultiHeadAttentio… │                   │            │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 30, 256)   │          0 │ bidirectional[0]… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 256)   │        512 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 128)       │     32,896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128)       │          0 │ dense_18[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 25)        │      3,225 │ dropout_7[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,153,561 (4.40 MB)
#  Trainable params: 1,153,561 (4.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Train Models

# %%
EPOCHS     = 40
BATCH_SIZE = 32

print("Training RNN ...")
history_rnn = rnn_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    callbacks=get_callbacks("rnn"), verbose=1)

print("Training LSTM ...")
history_lstm = lstm_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    callbacks=get_callbacks("lstm"), verbose=1)

print("Training GRU ...")
history_gru = gru_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    callbacks=get_callbacks("gru"), verbose=1)

print("Training BiLSTM+Attention ...")
history_attn = attention_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    callbacks=get_callbacks("attention"), verbose=1)
# Out:
# Training RNN ...
# Epoch 1/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 57s 377ms/step - accuracy: 0.0618 - loss: 3.2745 - val_accuracy: 0.1168 - val_loss: 3.0240 - learning_rate: 0.0010
# Epoch 2/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.
40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9946 - loss: 0.0308
# Epoch 34: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.9946 - loss: 0.0308 - val_accuracy: 0.9586 - val_loss: 0.1962 - learning_rate: 1.2500e-04
# Epoch 35/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9943 - loss: 0.0319 - val_accuracy: 0.9586 - val_loss: 0.1895 - learning_rate: 6.2500e-05
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 28.
# Training BiLSTM+Attention ...
# Epoch 1/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.0848 - loss: 3.2788 - val_accuracy: 0.3090 - val_loss: 2.2848 - learning_rate: 0.0010
# Epoch 2/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.2905 - loss: 2.2693 - val_accuracy: 0.6083 - val_loss: 1.1273 - learning_rate: 0.0010
# Epoch 3/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5657 - loss: 1.2641 - val_accuracy: 0.7762 - val_loss: 0.7884 - learning_rate: 0.0010
# Epoch 4/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7289 - loss: 0.8054 - val_accuracy: 0.7640 - val_loss: 0.7039 - learning_rate: 0.0010
# Epoch 5/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8033 - loss: 0.5793 - val_accuracy: 0.8443 - val_loss: 0.4682 - learning_rate: 0.0010
# Epoch 6/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8394 - loss: 0.4726 - val_accuracy: 0.8394 - val_loss: 0.5060 - learning_rate: 0.0010
# Epoch 7/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8760 - loss: 0.3554 - val_accuracy: 0.8832 - val_loss: 0.4466 - learning_rate: 0.0010
# Epoch 8/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9023 - loss: 0.2997 - val_accuracy: 0.8443 - val_loss: 0.5203 - learning_rate: 0.0010
# Epoch 9/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9015 - loss: 0.3296 - val_accuracy: 0.9148 - val_loss: 0.3320 - learning_rate: 0.0010
# Epoch 10/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9310 - loss: 0.2160 - val_accuracy: 0.8905 - val_loss: 0.4504 - learning_rate: 0.0010
# Epoch 11/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9542 - loss: 0.1447 - val_accuracy: 0.9100 - val_loss: 0.3718 - learning_rate: 0.0010
# Epoch 12/40
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9479 - loss: 0.1578
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9480 - loss: 0.1578 - val_accuracy: 0.8881 - val_loss: 0.5922 - learning_rate: 0.0010
# Epoch 13/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9527 - loss: 0.1399 - val_accuracy: 0.9051 - val_loss: 0.3458 - learning_rate: 5.0000e-04
# Epoch 14/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9821 - loss: 0.0675 - val_accuracy: 0.9197 - val_loss: 0.3877 - learning_rate: 5.0000e-04
# Epoch 15/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9848 - loss: 0.0546 - val_accuracy: 0.9392 - val_loss: 0.3212 - learning_rate: 5.0000e-04
# Epoch 16/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9853 - loss: 0.0476 - val_accuracy: 0.9392 - val_loss: 0.2498 - learning_rate: 5.0000e-04
# Epoch 17/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9871 - loss: 0.0373 - val_accuracy: 0.9367 - val_loss: 0.3861 - learning_rate: 5.0000e-04
# Epoch 18/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9936 - loss: 0.0264 - val_accuracy: 0.9319 - val_loss: 0.3702 - learning_rate: 5.0000e-04
# Epoch 19/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9873 - loss: 0.0415
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9873 - loss: 0.0415 - val_accuracy: 0.9319 - val_loss: 0.3619 - learning_rate: 5.0000e-04
# Epoch 20/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9937 - loss: 0.0267 - val_accuracy: 0.9489 - val_loss: 0.3008 - learning_rate: 2.5000e-04
# Epoch 21/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9965 - loss: 0.0131 - val_accuracy: 0.9465 - val_loss: 0.2882 - learning_rate: 2.5000e-04
# Epoch 22/40
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9973 - loss: 0.0099
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9973 - loss: 0.0099 - val_accuracy: 0.9343 - val_loss: 0.3456 - learning_rate: 2.5000e-04
# Epoch 23/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9930 - loss: 0.0154 - val_accuracy: 0.9465 - val_loss: 0.2948 - learning_rate: 1.2500e-04
# Epoch 24/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9991 - loss: 0.0068 - val_accuracy: 0.9465 - val_loss: 0.3023 - learning_rate: 1.2500e-04
# Epoch 25/40
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9987 - loss: 0.0065
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9987 - loss: 0.0066 - val_accuracy: 0.9465 - val_loss: 0.3012 - learning_rate: 1.2500e-04
# Epoch 26/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9993 - loss: 0.0059 - val_accuracy: 0.9489 - val_loss: 0.2874 - learning_rate: 6.2500e-05
# Epoch 27/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9991 - loss: 0.0070 - val_accuracy: 0.9465 - val_loss: 0.3028 - learning_rate: 6.2500e-05
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 20.

# %% [markdown]
# Re-build datasets for a shorter seq_len to compare

# %%
LEARNING_RATES = [0.001, 0.0005]
SEQ_LENGTHS    = [20, 30]          # two different temporal context windows

hp_results = []

for lr in LEARNING_RATES:
    for sl in SEQ_LENGTHS:
        print(f"--- lr={lr}  seq_len={sl} ---")

        # Truncate/pad existing sequences to sl (avoids re-extracting features)
        Xtr = X_train[:, :sl, :] if sl <= X_train.shape[1] else np.pad(
            X_train, ((0,0),(0, sl-X_train.shape[1]),(0,0)))
        Xv  = X_val[:,   :sl, :] if sl <= X_val.shape[1]   else np.pad(
            X_val,   ((0,0),(0, sl-X_val.shape[1]),  (0,0)))

        hp_inp = Input(shape=(sl, FEATURE_DIM))
        hx     = add_embedding_projection(hp_inp, 128)
        hx     = GRU(64, dropout=0.3)(hx)
        hx     = Dense(NUM_CLASSES, activation="softmax")(hx)
        hp_model = Model(hp_inp, hx)
        hp_model.compile(optimizer=Adam(lr),
                         loss="sparse_categorical_crossentropy",
                         metrics=["accuracy"])

        h = hp_model.fit(Xtr, y_train,
                         validation_data=(Xv, y_val),
                         epochs=15, batch_size=32, verbose=0,
                         callbacks=[EarlyStopping(patience=4,
                                     restore_best_weights=True)])
        best_val = max(h.history["val_accuracy"])
        hp_results.append({"lr": lr, "seq_len": sl, "val_acc": best_val})
        print(f"  best val_acc = {best_val:.4f}")

print("Hyperparameter sweep summary:")
for r in hp_results:
    print(f"  lr={r['lr']}  seq_len={r['seq_len']}  → val_acc={r['val_acc']:.4f}")
# Out:
# --- lr=0.001  seq_len=20 ---
#   best val_acc = 0.9416
# --- lr=0.001  seq_len=30 ---
#   best val_acc = 0.9489
# --- lr=0.0005  seq_len=20 ---
#   best val_acc = 0.9465
# --- lr=0.0005  seq_len=30 ---
#   best val_acc = 0.9319
# Hyperparameter sweep summary:
#   lr=0.001  seq_len=20  → val_acc=0.9416
#   lr=0.001  seq_len=30  → val_acc=0.9489
#   lr=0.0005  seq_len=20  → val_acc=0.9465
#   lr=0.0005  seq_len=30  → val_acc=0.9319

# %% [markdown]
# Evaluation on test set

# %%
def evaluate_model(model, X_test, y_test, name):
    loss, acc = model.evaluate(X_test, y_test, verbose=0)
    print(f"{name:25s}  test_loss={loss:.4f}  test_acc={acc:.4f}")
    return acc

print("Test-set results:")
acc_rnn   = evaluate_model(rnn_model,       X_test, y_test, "RNN")
acc_lstm  = evaluate_model(lstm_model,      X_test, y_test, "LSTM")
acc_gru   = evaluate_model(gru_model,       X_test, y_test, "GRU")
acc_attn  = evaluate_model(attention_model, X_test, y_test, "BiLSTM+Attention")
# Out:
# Test-set results:
# RNN                        test_loss=0.6811  test_acc=0.7788
# LSTM                       test_loss=0.3995  test_acc=0.8871
# GRU                        test_loss=0.1744  test_acc=0.9661
# BiLSTM+Attention           test_loss=0.2741  test_acc=0.9300

# %% [markdown]
# Model Comparision & Analysis

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ── Bar chart: test accuracy ─────────────────────────────────────────
model_names = ["RNN", "LSTM", "GRU", "BiLSTM+Attn"]
test_accs   = [acc_rnn, acc_lstm, acc_gru, acc_attn]
colors      = ["#4C72B0", "#55A868", "#C44E52", "#8172B2"]

bars = axes[0].bar(model_names, test_accs, color=colors, width=0.5)
axes[0].set_ylim(0, 1)
axes[0].set_title("Test Accuracy Comparison", fontsize=13)
axes[0].set_ylabel("Accuracy")
for bar, v in zip(bars, test_accs):
    axes[0].text(bar.get_x() + bar.get_width()/2, v + 0.01, f"{v:.3f}",
                 ha="center", va="bottom", fontsize=10)

# ── Training curves: val_accuracy ────────────────────────────────────
for hist, name, color in zip(
        [history_rnn, history_lstm, history_gru, history_attn],
        model_names, colors):
    axes[1].plot(hist.history["val_accuracy"], label=name, color=color)

axes[1].set_title("Validation Accuracy over Epochs", fontsize=13)
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Val Accuracy")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("/kaggle/working/model_comparison.png", dpi=150)
plt.show()

# ── Hyperparameter heatmap ────────────────────────────────────────────
import pandas as pd
hp_df = pd.DataFrame(hp_results)
pivot = hp_df.pivot(index="lr", columns="seq_len", values="val_acc")
plt.figure(figsize=(5, 3))
sns.heatmap(pivot, annot=True, fmt=".3f", cmap="YlGnBu")
plt.title("HP Search: val_acc (lr × seq_len)")
plt.tight_layout()
plt.savefig("/kaggle/working/hp_heatmap.png", dpi=150)
plt.show()

# %% [markdown]
# Confusion Matrix - BiLSTM + Attention

# %%
y_pred = np.argmax(attention_model.predict(X_test), axis=1)
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=classes, yticklabels=classes)
plt.xlabel("Predicted", fontsize=11)
plt.ylabel("Actual",    fontsize=11)
plt.title("Confusion Matrix — BiLSTM + Attention", fontsize=13)
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig("/kaggle/working/confusion_matrix.png", dpi=150)
plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# Classification Report

# %%
print("Classification Report (BiLSTM + Attention):")
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
# Classification Report (BiLSTM + Attention):
#                    precision    recall  f1-score   support
#
#    ApplyEyeMakeup       1.00      0.95      0.97        19
#     ApplyLipstick       0.94      1.00      0.97        15
#      BabyCrawling       0.93      0.76      0.84        17
#        Basketball       0.97      0.91      0.94        34
#        BenchPress       1.00      1.00      1.00        20
#            Biking       0.70      0.94      0.80        17
#       BlowDryHair       0.94      0.88      0.91        17
#           Bowling       1.00      0.95      0.97        20
#       CliffDiving       1.00      1.00      1.00        18
#       CricketShot       0.91      1.00      0.95        21
#     SumoWrestling       0.94      1.00      0.97        15
#           Surfing       1.00      1.00      1.00        16
#             Swing       0.94      0.94      0.94        17
#   TableTennisShot       1.00      1.00      1.00        18
#            TaiChi       0.76      1.00      0.87        13
#       TennisSwing       1.00      1.00      1.00        21
#       ThrowDiscus       1.00      0.88      0.94        17
# TrampolineJumping       1.00      0.73      0.85        15
#            Typing       0.94      1.00      0.97        17
#        UnevenBars       0.87      1.00      0.93        13
# VolleyballSpiking       0.88      1.00      0.94        15
#    WalkingWithDog       0.75      0.56      0.64        16
#       WallPushups       0.87      0.76      0.81        17
#    WritingOnBoard       1.00      0.95      0.97        19
#              YoYo       0.89      1.00      0.94        16
#
#          accuracy                           0.93       443
#         macro avg       0.93      0.93      0.92       443
#      weighted avg       0.94      0.93      0.93       443
